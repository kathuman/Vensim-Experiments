# %% [markdown]
# <a href="https://colab.research.google.com/github/kathuman/Vensim-Experiments/blob/main/20-12-Ventilation_vs_Infectivity/201208_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pysd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# We first load the model

# %%
model = pysd.read_vensim("201203_Infection_Model.mdl")
print(model.doc())
# Out:
#                                             Real Name  \
# 0                                         Air Density
# 1                                           Breathing
# 2                                     Clean Particles
# 3   Clean particle recovery due to vent and Virus ...
# 4                                   Contact Frequency
# 5      Contacts between suceptible and Virus Particle
# 6                       Exhalation of Clean Particles
# 7                                          FINAL TIME
# 8                                        INITIAL TIME
# 9                                            Infected
# 10                                     Infection Rate
# 11                        Overall Virus Concentration
# 12                          Person Viral Productivity
# 13         Probability of contact with Virus Particle
# 14                                      Recovery time
# 15                                        Room Volume
# 16                                            SAVEPER
# 17                                Suceptible Contacts
# 18                                        Susceptible
# 19                                          TIME STEP
# 20                               Ventilation strength
# 21                                        Virus Decay
# 22                                   Virus Decay Time
# 23                                   Virus Production
# 24                      Virus loss due to Ventilation
# 25                                    Virus particles
# 26                                        infectivity
# 27                                      recovery rate
#
#                                               Py Name           Unit  \
# 0                                         air_density        b'g/m3'
# 1                                           breathing       b'g/Day'
# 2                                     clean_particles           b'g'
# 3   clean_particle_recovery_due_to_vent_and_virus_...            b''
# 4                                   contact_frequency       b'1/Day'
# 5      contacts_between_suceptible_and_virus_particle            b''
# 6                       exhalation_of_clean_particles       b'g/Day'
# 7                                          final_time         b'Day'
# 8                                        initial_time         b'Day'
# 9                                            infected      b'Person'
# 10                                     infection_rate  b'Person/Day'
# 11                        overall_virus_concentration        b'Dmnl'
# 12                          person_viral_productivity    b'g/Person'
# 13         probability_of_contact_with_virus_particle        b'Dmnl'
# 14                                      recovery_time         b'Day'
# 15                                        room_volume          b'm3'
# 16                                            saveper         b'Day'
# 17                                suceptible_contacts  b'Person/Day'
# 18                                        susceptible      b'Person'
# 19                                          time_step         b'Day'
# 20                               ventilation_strength       b'g/Day'
# 21                                        virus_decay       b'g/Day'
# 22                                   virus_decay_time         b'Day'
# 23                                   virus_production       b'g/Day'
# 24                      virus_loss_due_to_ventilation       b'g/Day'
# 25                                    virus_particles           b'g'
# 26                                        infectivity        b'Dmnl'
# 27                                      recovery_rate  b'Person/Day'
#
#                   Lims       Type  \
# 0         (None, None)   constant
# 1         (None, None)  component
# 2         (None, None)  component
# 3         (None, None)  component
# 4         (None, None)   constant
# 5         (None, None)  component
# 6         (None, None)  component
# 7         (None, None)   constant
# 8         (None, None)   constant
# 9         (None, None)  component
# 10        (None, None)  component
# 11        (None, None)  component
# 12        (None, None)   constant
# 13        (None, None)  component
# 14        (None, None)   constant
# 15        (None, None)   constant
# 16         (0.0, None)  component
# 17        (None, None)  component
# 18        (None, None)  component
# 19         (0.0, None)   constant
# 20  (0.0, 2000.0, 1.0)   constant
# 21        (None, None)  component
# 22        (None, None)   constant
# 23        (None, None)  component
# 24        (None, None)  component
# 25        (None, None)  component
# 26        (None, None)   constant
# 27        (None, None)  component
#
#                                                   Eqn  \
# 0                                             b'1225'
# 1                                  b'0.0024*Infected'
# 2   b'INTEG ( Clean particle recovery due to vent ...
# 3        b'Virus Decay+Virus loss due to Ventilation'
# 4                                            b'10000'
# 5   b'Suceptible Contacts*Probability of contact w...
# 6                       b'Breathing-Virus Production'
# 7                                              b'250'
# 8                                                b'0'
# 9         b'INTEG ( Infection Rate-recovery rate, 1)'
# 10  b'Contacts between suceptible and Virus Partic...
# 11                 b'Virus particles/Clean Particles'
# 12                                             b'0.4'
# 13                 b'Virus particles/Clean Particles'
# 14                                              b'14'
# 15                                           b'5*5*4'
# 16                                       b'TIME STEP'
# 17                   b'Susceptible*Contact Frequency'
# 18       b'INTEG ( recovery rate-Infection Rate, 10)'
# 19                                       b'0.0078125'
# 20                                            b'2000'
# 21                b'Virus particles/Virus Decay Time'
# 22                                              b'14'
# 23              b'Infected*Person Viral Productivity'
# 24  b'Overall Virus Concentration*Ventilation stre...
# 25  b'INTEG ( Virus Production-Virus Decay-Virus l...
# 26                                            b'0.05'
# 27                          b'Infected/Recovery time'
#
#                                             Comment
# 0   b'https://en.wikipedia.org/wiki/Density_of_air'
# 1                                               b''
# 2                                               b''
# 3                                               b''
# 4                                               b''
# 5                                               b''
# 6                                               b''
# 7             b'The final time for the simulation.'
# 8           b'The initial time for the simulation.'
# 9                                               b''
# 10                                              b''
# 11                                              b''
# 12                                              b''
# 13                                              b''
# 14                                              b''
# 15        b'Room with a volume of 5 x 5 x 4 meters'
# 16    b'The frequency with which output is stored.'
# 17                                              b''
# 18                                              b''
# 19             b'The time step for the simulation.'
# 20                                              b''
# 21                                              b''
# 22                                              b''
# 23                                              b''
# 24                                              b''
# 25                                              b''
# 26                                              b''
# 27                                              b''

# %%
model.run(return_columns=['Infected', 'Susceptible']).plot()
plt.xlabel('Days')
plt.ylabel('Persons')
plt.title('Evolution of Stocks')
plt.legend()
